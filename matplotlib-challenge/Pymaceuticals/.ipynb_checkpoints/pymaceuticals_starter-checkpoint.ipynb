# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
md_df = pd.read_csv(mouse_drug_data_to_load)
ct_df = pd.read_csv(clinical_trial_data_to_load)

# Combine the data into a single dataset
fulldf = pd.merge(md_df, ct_df, how="left", on="Mouse ID")

# Display the data table for preview
fulldf.columns = [c.replace(' ', '_') for c in fulldf.columns]
fulldf.columns = [c.replace('(', '') for c in fulldf.columns]
fulldf.columns = [c.replace(')', '') for c in fulldf.columns]
fulldf
# Out:
#      Mouse_ID      Drug  Timepoint  Tumor_Volume_mm3  Metastatic_Sites
# 0        f234  Stelasyn          0         45.000000                 0
# 1        f234  Stelasyn          5         47.313491                 0
# 2        f234  Stelasyn         10         47.904324                 0
# 3        f234  Stelasyn         15         48.735197                 1
# 4        f234  Stelasyn         20         51.112713                 2
# ...       ...       ...        ...               ...               ...
# 1901     j235   Placebo          0         45.000000                 0
# 1902     j235   Placebo          5         46.588820                 0
# 1903     j235   Placebo         10         48.018788                 1
# 1904     j235   Placebo         15         51.161138                 1
# 1905     j235   Placebo         20         52.942902                 1
#
# [1906 rows x 5 columns]

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
meandf = (fulldf.groupby(['Drug','Timepoint']).mean()['Tumor_Volume_mm3'])
# Convert to DataFrame
meandf = pd.DataFrame(meandf)
# Preview DataFrame
meandf.head()
# Out:
#                      Tumor_Volume_mm3
# Drug      Timepoint
# Capomulin 0                 45.000000
#           5                 44.266086
#           10                43.084291
#           15                42.064317
#           20                40.716325

# %%
semdf = (fulldf.groupby(['Drug','Timepoint']).sem()['Tumor_Volume_mm3'])
semdf = pd.DataFrame(semdf)
semdf.head()
# Out:
#                      Tumor_Volume_mm3
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.448593
#           10                 0.702684
#           15                 0.838617
#           20                 0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames
meandf = meandf.reset_index()
meanPdf = meandf.pivot(index="Timepoint", columns="Drug")['Tumor_Volume_mm3']
semdf = semdf.reset_index()
semPdf = semdf.pivot(index="Timepoint", columns="Drug")['Tumor_Volume_mm3']
# Preview that Reformatting worked
meanPdf
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
semPdf
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (with Error Bars)
plt.figure(figsize=(8,5))
plt.errorbar(meanPdf.index, meanPdf["Capomulin"], yerr=semPdf["Capomulin"], marker="o", color="r", markersize=5, linestyle="dashed", linewidth=0.5, capsize=3)
plt.errorbar(meanPdf.index, meanPdf["Infubinol"], yerr=semPdf["Infubinol"], marker="x", color="b", markersize=5, linestyle="dashed", linewidth=0.5, capsize=3)
plt.errorbar(meanPdf.index, meanPdf["Ketapril"], yerr=semPdf["Ketapril"], marker="+", color="g", markersize=5, linestyle="dashed", linewidth=0.5, capsize=3)
plt.errorbar(meanPdf.index, meanPdf["Placebo"], yerr=semPdf["Placebo"], marker="^", color="k", markersize=5, linestyle="dashed", linewidth=0.5, capsize=3)


plt.ylim(20,80)
plt.xlim(0,45)
plt.title("Tumor Response to Treatment", fontsize=20)
plt.ylable("Tumor_Volume_mm3", fontsize=14)
plt.xlable("Time (days)", fontsize=14)
plt.grid(linestyle="dashed")
plt.legend(loc="best", fontsize="small", fancybox=True)
plt.savefig("Fig1.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7ee7e5cb3c5c> in <module>
#      10 plt.xlim(0,45)
#      11 plt.title("Tumor Response to Treatment", fontsize=20)
# ---> 12 plt.ylable("Tumor_Volume_mm3", fontsize=14)
#      13 plt.xlable("Time (days)", fontsize=14)
#      14 plt.grid(linestyle="dashed")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
meanMSdf = (fulldf.groupby(['Drug','Timepoint']).mean()['Metastatic_Sites'])
# Convert to DataFrame
meanMSdf = pd.DataFrame(meanMSdf)
# Preview DataFrame
meanMSdf.head()
# Out:
#                      Metastatic_Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
semMSdf = (fulldf.groupby(['Drug','Timepoint']).sem()['Metastatic_Sites'])
# Convert to DataFrame
semMSdf = pd.DataFrame(semMSdf)
# Preview DataFrame
semMSdf.head()
# Out:
#                      Metastatic_Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames
# Minor Data Munging to Re-Format the Data Frames
meanMSdf = meanMSdf.reset_index()
meanMSPdf = meanMSdf.pivot(index="Timepoint", columns="Drug")['Metastatic_Sites']
semMSdf = semMSdf.reset_index()
semMSPdf = semMSdf.pivot(index="Timepoint", columns="Drug")['Metastatic_Sites']
# Preview that Reformatting worked
meanMSPdf
# Preview that Reformatting worked
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
semMSPdf
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (with Error Bars)
plt.figure(figsize=(8,5))
plt.errorbar(meanMSPdf.index, meanMSPdf["Capomulin"], yerr=semMSPdf["Capomulin"], marker="o", color="r", markersize=5, linestyle="dashed", linewidth=0.5, capsize=3)
plt.errorbar(meanMSPdf.index, meanMSPdf["Infubinol"], yerr=semMSPdf["Infubinol"], marker="x", color="b", markersize=5, linestyle="dashed", linewidth=0.5, capsize=3)
plt.errorbar(meanMSPdf.index, meanMSPdf["Ketapril"], yerr=semMSPdf["Ketapril"], marker="+", color="g", markersize=5, linestyle="dashed", linewidth=0.5, capsize=3)
plt.errorbar(meanMSPdf.index, meanMSPdf["Placebo"], yerr=semMSPdf["Placebo"], marker="^", color="k", markersize=5, linestyle="dashed", linewidth=0.5, capsize=3)


plt.ylim(0,4)
plt.xlim(0,45)
plt.title("Metastatic Spread During Treatment", fontsize=20)
plt.ylable("Metastatic Sites", fontsize=14)
plt.xlable("Treatment duration (days)", fontsize=14)
plt.grid(linestyle="dashed")
plt.legend(loc="best", fontsize="small", fancybox=True)
plt.savefig("Fig2.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-1d4c92696c2a> in <module>
#      10 plt.xlim(0,45)
#      11 plt.title("Metastatic Spread During Treatment", fontsize=20)
# ---> 12 plt.ylable("Metastatic Sites", fontsize=14)
#      13 plt.xlable("Treatment duration (days)", fontsize=14)
#      14 plt.grid(linestyle="dashed")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
scdf = (fulldf.groupby(['Drug','Timepoint']).count()['Tumor_Volume_mm3'])
# Convert to DataFrame
scdf = pd.DataFrame({"Mouse Count": scdf})

# Preview DataFrame
scdf
# Out:
#                      Mouse Count
# Drug      Timepoint
# Capomulin 0                   25
#           5                   25
#           10                  25
#           15                  24
#           20                  23
# ...                          ...
# Zoniferol 25                  16
#           30                  15
#           35                  14
#           40                  14
#           45                  14
#
# [100 rows x 1 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
scdf = scdf.reset_index()
scPdf = scdf.pivot(index="Timepoint", columns="Drug")['Mouse Count']

# Preview that Reformatting worked
scPdf
# Preview the Data Frame
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# ...

# %%
# Generate the Plot (Accounting for percentages)
plt.figure(figsize=(8,5))
plt.plot(100 * scPdf["Capomulin"], yerr=scPdf["Capomulin"]/25, "ro", linestyle="dashed", markersize=5, linestyle="dashed", linewidth=0.5)
plt.plot(100 * scPdf["Infubinol"], yerr=scPdf["Infubinol"]/25, "ro",linestyle="dashed", markersize=5, linestyle="dashed", linewidth=0.5)
plt.plot(100 * scPdf["Ketapril"], yerr=scPdf["Ketapril"]/25, "ro",linestyle="dashed", markersize=5, linestyle="dashed", linewidth=0.5)
plt.plot(100 * scPdf["Capomulin"], yerr=scPdf["Placebo"]/25, "ro",linestyle="dashed", markersize=5, linestyle="dashed", linewidth=0.5)

plt.ylim(0,4)
plt.xlim(0,45)
plt.title("Survival During Treatment", fontsize=20)
plt.ylable("Metastatic Sites", fontsize=14)
plt.xlable("Time of day", fontsize=14)
plt.grid(linestyle="dashed")
plt.legend(loc="best", fontsize="small", fancybox=True)
# Save the Figure
plt.savefig("Fig3.png")
plt.show()

# Show the Figure
plt.show()
# Out:
#   File "<ipython-input-15-9a4acf85731e>", line 3
#     plt.plot(100 * scPdf["Capomulin"], yerr=scPdf["Capomulin"]/25, "ro", linestyle="dashed", markersize=5, linestyle="dashed", linewidth=0.5)
#                                                                   ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
tumor_pct_change = 100 * (tumor_vols_pivot_mean.iloc[-1] - tumor_vols_pivot_mean.iloc[0] / tumor_vols_pivot_mean.iloc[0])
# Display the data to confirm
tumor_pct_change
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-e98c59103663> in <module>
#       1 # Calculate the percent changes for each drug
# ----> 2 tumor_pct_change = 100 * (tumor_vols_pivot_mean.iloc[-1] - tumor_vols_pivot_mean.iloc[0] / tumor_vols_pivot_mean.iloc[0])
#       3 # Display the data to confirm
#       4 tumor_pct_change
#
# NameError: name 'tumor_vols_pivot_mean' is not defined

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
